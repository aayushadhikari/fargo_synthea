# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.5.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages (from faker) (2025.2)
# Downloading faker-37.5.3-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.6 MB/s eta 0:00:00-:--:--
# Installing collected packages: faker
# Successfully installed faker-37.5.3

# %%
import requests
import json
import time
import os
from faker import Faker
import random

OLLAMA_API = "http://localhost:11434/api/generate"
OLLAMA_MODEL = "gpt-oss:20b"
OUTPUT_FILE = "deid_dataset.jsonl"
MAX_LEN = 600  # max chars per section
DELAY = 3      # seconds between calls

fake = Faker()

# concise mini-note generation prompt with inline Faker injection
def build_prompt():
    phi = {
        "name": fake.name(),
        "dob": fake.date_of_birth(minimum_age=20, maximum_age=85).strftime("%m/%d/%Y"),
        "ssn": fake.ssn(),
        "address": fake.address().replace("\n", ", "),
        "phone": fake.phone_number(),
        "email": fake.email(),
        "passport": fake.bothify(text='??########'),
        "provider": fake.name(),
        "organization": fake.company(),
        "hospital": f"{fake.last_name()} Medical Center",
        "visit_date": fake.date_between(start_date='-2y', end_date='today').strftime("%m/%d/%Y")
    }

    return f"""
You are generating concise training data to help a medical AI model learn to detect and redact Protected Health Information (PHI) from clinical notes.

Each example should have two sections:
1. <data_with_phi>: A short, realistic clinical note (3 to 5 sentences) that includes PHI like patient name, SSN, birthdate, address, phone number, passport number, provider name, organization name, etc.
2. <data_hipaa_compliant>: A redacted version with [REDACTED] or placeholders like [DOB], [NAME], [HOSPITAL], while preserving medically relevant content (conditions, meds, vitals, symptoms).

Please be creative with the examples. Below I have an example of how to use the phi info, but feel free to restructure and scatter PHI in creative ways throughout the text. Also use diverse kinds of visit reasons and findings.
<example>
  <data_with_phi>
    Patient: {phi['name']}, born on {phi['dob']} (SSN: {phi['ssn']}) came to {phi['hospital']} on {phi['visit_date']} complaining of abdominal pain and nausea. 
    She was evaluated by Dr. {phi['provider']} and prescribed ondansetron and fluids. 
    Her address is {phi['address']}, phone: {phi['phone']}, email: {phi['email']}, passport: {phi['passport']}. 
    Follow-up with {phi['organization']} was recommended.
  </data_with_phi>

  <data_hipaa_compliant>
    Patient: [NAME], born on [DOB] (SSN: [REDACTED]) came to [HOSPITAL] on [REDACTED] complaining of abdominal pain and nausea. 
    She was evaluated by Dr. [REDACTED] and prescribed ondansetron and fluids. 
    Her address is [ADDRESS], phone: [PHONE], email: [EMAIL], passport: [REDACTED]. 
    Follow-up with [ORGANIZATION] was recommended.
  </data_hipaa_compliant>
</example>
"""

def call_ollama(prompt, model=OLLAMA_MODEL):
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }
    response = requests.post(OLLAMA_API, json=payload)
    if response.status_code == 200:
        return response.json()["response"]
    else:
        print(f"❌ Request failed: {response.status_code} - {response.text}")
        return None

def parse_response(text):
    try:
        data_with_phi = text.split("<data_with_phi>")[1].split("</data_with_phi>")[0].strip()
        data_hipaa_compliant = text.split("<data_hipaa_compliant>")[1].split("</data_hipaa_compliant>")[0].strip()

        if len(data_with_phi) > MAX_LEN or len(data_hipaa_compliant) > MAX_LEN:
            print("⚠️ Skipping too-long example")
            return None

        return {
            "data_with_phi": data_with_phi,
            "data_hipaa_compliant": data_hipaa_compliant
        }
    except Exception as e:
        print(f"⚠️ Failed to parse response: {e}")
        return None

def load_existing_examples(filepath):
    if not os.path.exists(filepath):
        return set()
    with open(filepath, "r", encoding="utf-8") as f:
        return set(json.loads(line)["data_with_phi"] for line in f if line.strip())

def save_to_jsonl(data, filename=OUTPUT_FILE):
    with open(filename, "a", encoding="utf-8") as f:
        f.write(json.dumps(data, ensure_ascii=False) + "\n")

def generate_dataset(n_total=5000, delay=DELAY):
    seen = load_existing_examples(OUTPUT_FILE)
    count_existing = len(seen)
    print(f"📂 Found {count_existing} existing examples. Target: {n_total}")

    for i in range(count_existing, n_total):
        print(f"\n👉 Generating example {i+1}/{n_total}")
        prompt = build_prompt()
        raw_output = call_ollama(prompt)
        if raw_output:
            parsed = parse_response(raw_output)
            if parsed and parsed["data_with_phi"] not in seen:
                save_to_jsonl(parsed)
                seen.add(parsed["data_with_phi"])
                print(f"✅ Saved example {i+1}")
            else:
                print("⚠️ Duplicate or parse issue, skipping")
        else:
            print("⚠️ No response from model")
        time.sleep(delay)

if __name__ == "__main__":
    generate_dataset(n_total=5000)
# Out:
# 📂 Found 154 existing examples. Target: 5000
#
# 👉 Generating example 155/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 156/5000
# ✅ Saved example 156
#
# 👉 Generating example 157/5000
# ✅ Saved example 157
#
# 👉 Generating example 158/5000
# ✅ Saved example 158
#
# 👉 Generating example 159/5000
# ✅ Saved example 159
#
# 👉 Generating example 160/5000
# ✅ Saved example 160
#
# 👉 Generating example 161/5000
# ✅ Saved example 161
#
# 👉 Generating example 162/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 163/5000
# ✅ Saved example 163
#
# 👉 Generating example 164/5000
# ✅ Saved example 164
#
# 👉 Generating example 165/5000
# ✅ Saved example 165
#
# 👉 Generating example 166/5000
# ✅ Saved example 166
#
# 👉 Generating example 167/5000
# ✅ Saved example 167
#
# 👉 Generating example 168/5000
# ✅ Saved example 168
#
# 👉 Generating example 169/5000
# ✅ Saved example 169
#
# 👉 Generating example 170/5000
# ✅ Saved example 170
#
# 👉 Generating example 171/5000
# ✅ Saved example 171
#
# 👉 Generating example 172/5000
# ✅ Saved example 172
#
# 👉 Generating example 173/5000
# ✅ Saved example 173
#
# 👉 Generating example 174/5000
# ✅ Saved example 174
#
# 👉 Generating example 175/5000
# ✅ Saved example 175
#
# 👉 Generating example 176/5000
# ✅ Saved example 176
#
# 👉 Generating example 177/5000
# ✅ Saved example 177
#
# 👉 Generating example 178/5000
# ✅ Saved example 178
#
# 👉 Generating example 179/5000
# ✅ Saved example 179
#
# 👉 Generating example 180/5000
# ✅ Saved example 180
#
# 👉 Generating example 181/5000
# ✅ Saved example 181
#
# 👉 Generating example 182/5000
# ✅ Saved example 182
#
# 👉 Generating example 183/5000
# ✅ Saved example 183
#
# 👉 Generating example 184/5000
# ✅ Saved example 184
#
# 👉 Generating example 185/5000
# ✅ Saved example 185
#
# 👉 Generating example 186/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 187/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 188/5000
# ✅ Saved example 188
#
# 👉 Generating example 189/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 190/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 191/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 192/5000
# ✅ Saved example 192
#
# 👉 Generating example 193/5000
# ✅ Saved example 193
#
# 👉 Generating example 194/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 195/5000
# ✅ Saved example 195
#
# 👉 Generating example 196/5000
# ✅ Saved example 196
#
# 👉 Generating example 197/5000
# ✅ Saved example 197
#
# 👉 Generating example 198/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 199/5000
# ✅ Saved example 199
#
# 👉 Generating example 200/5000
# ✅ Saved example 200
#
# 👉 Generating example 201/5000
# ✅ Saved example 201
#
# 👉 Generating example 202/5000
# ✅ Saved example 202
#
# 👉 Generating example 203/5000
# ✅ Saved example 203
#
# 👉 Generating example 204/5000
# ✅ Saved example 204
#
# 👉 Generating example 205/5000
# ✅ Saved example 205
#
# 👉 Generating example 206/5000
# ✅ Saved example 206
#
# 👉 Generating example 207/5000
# ✅ Saved example 207
#
# 👉 Generating example 208/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 209/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 210/5000
# ✅ Saved example 210
#
# 👉 Generating example 211/5000
# ✅ Saved example 211
#
# 👉 Generating example 212/5000
# ✅ Saved example 212
#
# 👉 Generating example 213/5000
# ✅ Saved example 213
#
# 👉 Generating example 214/5000
# ✅ Saved example 214
#
# 👉 Generating example 215/5000
# ✅ Saved example 215
#
# 👉 Generating example 216/5000
# ✅ Saved example 216
#
# 👉 Generating example 217/5000
# ✅ Saved example 217
#
# 👉 Generating example 218/5000
# ✅ Saved example 218
#
# 👉 Generating example 219/5000
# ✅ Saved example 219
#
# 👉 Generating example 220/5000
# ✅ Saved example 220
#
# 👉 Generating example 221/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 222/5000
# ✅ Saved example 222
#
# 👉 Generating example 223/5000
# ✅ Saved example 223
#
# 👉 Generating example 224/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 225/5000
# ✅ Saved example 225
#
# 👉 Generating example 226/5000
# ✅ Saved example 226
#
# 👉 Generating example 227/5000
# ✅ Saved example 227
#
# 👉 Generating example 228/5000
# ✅ Saved example 228
#
# 👉 Generating example 229/5000
# ✅ Saved example 229
#
# 👉 Generating example 230/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 231/5000
# ✅ Saved example 231
#
# 👉 Generating example 232/5000
# ✅ Saved example 232
#
# 👉 Generating example 233/5000
# ✅ Saved example 233
#
# 👉 Generating example 234/5000
# ✅ Saved example 234
#
# 👉 Generating example 235/5000
# ✅ Saved example 235
#
# 👉 Generating example 236/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 237/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 238/5000
# ✅ Saved example 238
#
# 👉 Generating example 239/5000
# ✅ Saved example 239
#
# 👉 Generating example 240/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 241/5000
# ✅ Saved example 241
#
# 👉 Generating example 242/5000
# ✅ Saved example 242
#
# 👉 Generating example 243/5000
# ✅ Saved example 243
#
# 👉 Generating example 244/5000
# ✅ Saved example 244
#
# 👉 Generating example 245/5000
# ✅ Saved example 245
#
# 👉 Generating example 246/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 247/5000
# ✅ Saved example 247
#
# 👉 Generating example 248/5000
# ✅ Saved example 248
#
# 👉 Generating example 249/5000
# ✅ Saved example 249
#
# 👉 Generating example 250/5000
# ✅ Saved example 250
#
# 👉 Generating example 251/5000
# ✅ Saved example 251
#
# 👉 Generating example 252/5000
# ✅ Saved example 252
#
# 👉 Generating example 253/5000
# ✅ Saved example 253
#
# 👉 Generating example 254/5000
# ✅ Saved example 254
#
# 👉 Generating example 255/5000
# ✅ Saved example 255
#
# 👉 Generating example 256/5000
# ✅ Saved example 256
#
# 👉 Generating example 257/5000
# ✅ Saved example 257
#
# 👉 Generating example 258/5000
# ✅ Saved example 258
#
# 👉 Generating example 259/5000
# ✅ Saved example 259
#
# 👉 Generating example 260/5000
# ✅ Saved example 260
#
# 👉 Generating example 261/5000
# ✅ Saved example 261
#
# 👉 Generating example 262/5000
# ✅ Saved example 262
#
# 👉 Generating example 263/5000
# ✅ Saved example 263
#
# 👉 Generating example 264/5000
# ✅ Saved example 264
#
# 👉 Generating example 265/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 266/5000
# ✅ Saved example 266
#
# 👉 Generating example 267/5000
# ✅ Saved example 267
#
# 👉 Generating example 268/5000
# ✅ Saved example 268
#
# 👉 Generating example 269/5000
# ✅ Saved example 269
#
# 👉 Generating example 270/5000
# ✅ Saved example 270
#
# 👉 Generating example 271/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 272/5000
# ✅ Saved example 272
#
# 👉 Generating example 273/5000
# ✅ Saved example 273
#
# 👉 Generating example 274/5000
# ✅ Saved example 274
#
# 👉 Generating example 275/5000
# ✅ Saved example 275
#
# 👉 Generating example 276/5000
# ✅ Saved example 276
#
# 👉 Generating example 277/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 278/5000
# ✅ Saved example 278
#
# 👉 Generating example 279/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 280/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 281/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 282/5000
# ✅ Saved example 282
#
# 👉 Generating example 283/5000
# ✅ Saved example 283
#
# 👉 Generating example 284/5000
# ✅ Saved example 284
#
# 👉 Generating example 285/5000
# ✅ Saved example 285
#
# 👉 Generating example 286/5000
# ✅ Saved example 286
#
# 👉 Generating example 287/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 288/5000
# ✅ Saved example 288
#
# 👉 Generating example 289/5000
# ✅ Saved example 289
#
# 👉 Generating example 290/5000
# ✅ Saved example 290
#
# 👉 Generating example 291/5000
# ✅ Saved example 291
#
# 👉 Generating example 292/5000
# ✅ Saved example 292
#
# 👉 Generating example 293/5000
# ✅ Saved example 293
#
# 👉 Generating example 294/5000
# ✅ Saved example 294
#
# 👉 Generating example 295/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 296/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 297/5000
# ✅ Saved example 297
#
# 👉 Generating example 298/5000
# ✅ Saved example 298
#
# 👉 Generating example 299/5000
# ✅ Saved example 299
#
# 👉 Generating example 300/5000
# ✅ Saved example 300
#
# 👉 Generating example 301/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 302/5000
# ✅ Saved example 302
#
# 👉 Generating example 303/5000
# ✅ Saved example 303
#
# 👉 Generating example 304/5000
# ✅ Saved example 304
#
# 👉 Generating example 305/5000
# ✅ Saved example 305
#
# 👉 Generating example 306/5000
# ✅ Saved example 306
#
# 👉 Generating example 307/5000
# ✅ Saved example 307
#
# 👉 Generating example 308/5000
# ✅ Saved example 308
#
# 👉 Generating example 309/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 310/5000
# ✅ Saved example 310
#
# 👉 Generating example 311/5000
# ✅ Saved example 311
#
# 👉 Generating example 312/5000
# ✅ Saved example 312
#
# 👉 Generating example 313/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 314/5000
# ✅ Saved example 314
#
# 👉 Generating example 315/5000
# ✅ Saved example 315
#
# 👉 Generating example 316/5000
# ✅ Saved example 316
#
# 👉 Generating example 317/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 318/5000
# ✅ Saved example 318
#
# 👉 Generating example 319/5000
# ✅ Saved example 319
#
# 👉 Generating example 320/5000
# ✅ Saved example 320
#
# 👉 Generating example 321/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 322/5000
# ✅ Saved example 322
#
# 👉 Generating example 323/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 324/5000
# ✅ Saved example 324
#
# 👉 Generating example 325/5000
# ✅ Saved example 325
#
# 👉 Generating example 326/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 327/5000
# ✅ Saved example 327
#
# 👉 Generating example 328/5000
# ✅ Saved example 328
#
# 👉 Generating example 329/5000
# ✅ Saved example 329
#
# 👉 Generating example 330/5000
# ✅ Saved example 330
#
# 👉 Generating example 331/5000
# ✅ Saved example 331
#
# 👉 Generating example 332/5000
# ✅ Saved example 332
#
# 👉 Generating example 333/5000
# ✅ Saved example 333
#
# 👉 Generating example 334/5000
# ✅ Saved example 334
#
# 👉 Generating example 335/5000
# ✅ Saved example 335
#
# 👉 Generating example 336/5000
# ✅ Saved example 336
#
# 👉 Generating example 337/5000
# ✅ Saved example 337
#
# 👉 Generating example 338/5000
# ⚠️ Skipping too-long example
# ⚠️ Duplicate or parse issue, skipping
#
# 👉 Generating example 339/5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 119
#     116         time.sleep(delay)
#     118 if __name__ == "__main__":
# --> 119     generate_dataset(n_total=5000)
#
# Cell In[3], line 105, in generate_dataset(n_total, delay)
#     103 print(f"\n👉 Generating example {i+1}/{n_total}")
#     104 prompt = build_prompt()
# --> 105 raw_output = call_ollama(prompt)
#     106 if raw_output:
#     107     parsed = parse_response(raw_output)
#
# Cell In[3], line 63, in call_ollama(prompt, model)
#      57 def call_ollama(prompt, model=OLLAMA_MODEL):
#      58     payload = {
#      59         "model": model,
#      60         "prompt": prompt,
#      61         "stream": False
#      62     }
# ---> 63     response = requests.post(OLLAMA_API, json=payload)
#      64     if response.status_code == 200:
#      65         return response.json()["response"]
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/anaconda3/envs/health-hw7/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# KeyboardInterrupt:
